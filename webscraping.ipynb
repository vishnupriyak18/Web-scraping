# %%
import os
import pandas as pd
import selenium 
from selenium import webdriver
url = "https://www.qualitytrade.com/categories"
driver = webdriver.Chrome()
driver.get(url)

# %%
agri_bev = driver.find_elements_by_xpath('//*[@id="agriculture-food"]')[0].text
ener_env = driver.find_elements_by_xpath('//*[@id="energy-environment"]')[0].text
appa_textiles=driver.find_elements_by_xpath('//*[@id="apparel-textiles"]')[0].text
auto_trans = driver.find_elements_by_xpath('//*[@id="automobiles-transportation"]')[0].text
healt_beaut = driver.find_elements_by_xpath('//*[@id="health-beauty"]')[0].text
chem_metal = driver.find_elements_by_xpath('//*[@id="chemicals-minerals-metallurgy"]')[0].text
const_estate=driver.find_elements_by_xpath('//*[@id="construction-real-estate"]')[0].text
electronics=driver.find_elements_by_xpath('//*[@id="electronics-home-appliances-security"]')[0].text
telecom=driver.find_elements_by_xpath('//*[@id="electronics-components-telecommunications"]')[0].text
jwel=driver.find_elements_by_xpath('//*[@id="accessories-jewelries-bags"]')[0].text
gifts=driver.find_elements_by_xpath('//*[@id="gifts-toys-sports-entertainment"]')[0].text
furni=driver.find_elements_by_xpath('//*[@id="home-furniture-lights"]')[0].text
tools=driver.find_elements_by_xpath('//*[@id="machinery-tools-hardware"]')[0].text
instrum=driver.find_elements_by_xpath('//*[@id="measurement-analysis-instruments"]')[0].text
pack=driver.find_elements_by_xpath('//*[@id="packaging-advertising-office"]')[0].text
service=driver.find_elements_by_xpath('//*[@id="services"]')[0].text
end=driver.find_elements_by_xpath('//*[@id="root"]/div/section/header')[0].text
x=(agri_bev,ener_env,appa_textiles,auto_trans,healt_beaut,chem_metal,const_estate,electronics,telecom,jwel,gifts,furni,tools,instrum,pack,service)

import json

with open('x','w') as outfile:
 json.dump(x,outfile)
print('done')
# Out:
# done

# %%
import os
from settings import PROJECT_ROOT
df=pd.DataFrame(x)
y=os.path.basename(os.path.normpath(path))
new_path='C:\\Users\\jayar\\Desktop\\webscrap\\otp.xlsx'+y
z=pd.ExcelWriter(new_path , engine='xlswriter')
df.to_excel(z)
y.save()

# %%
Agriculture & Food,
Agriculture,
277 Products,
75 Suppliers,
27 Countries,
Agricultural Equipment,
Agricultural Waste,
Animal Feed,
Animal Products,
Beans,
Cacao Beans,
Coffee Beans,
Fermentation Tannins,
Fresh Fruit,
Fresh Vegetables,
Grain,
Herbal Cigars & Cigarettes,
Mushrooms & Truffles,
Nuts & Kernels,
Ornamental Plants,
Other Agriculture Products,
Plant & Animal Oil,
Plant Seeds & Bulbs,
Post Fermentation Tannins,
Timber Raw Materials,
Vanilla Beans,
Less,
Food & Beverage,
1162 Products,
180 Suppliers,
49 Countries,
Alcoholic Beverage,
Baby Food,
Baked Goods,
Bean Products,
Canned Food,
Coffee,
Confectionery,
Dairy Products,
Drinking Water,
Drinks,
Egg Products,
Food Ingredients,
Fruit Products,
Grain Products,
Honey & Honey Products,
Infused Oils,
Instant Food,
Meat & Poultry,
Other Food & Beverage,
Seafood,
Seasonings & Condiments,
Snacks,
37 Suppliers,
15 Countries,
Advertising Equipment,
Cargo & Storage Equipment,
Commercial Laundry Equipment,
Financial Equipment,
Funeral Supplies,
Grease Traps,
Other Service Equipment,
Restaurant & Hotel Supplies,
Store & Supermarket Supplies,
Trade Show Equipment,
Vending Machines,
Wedding Supplies,
Less,
Services,
Services,
4036 Products,
1002 Suppliers,
77 Countries,
Accommodation Services,
Accounting Services,
Agricultural Services,
Amusement and Recreation Services,
Apparel Services,
Architectural Services,
Automotive Services,
Aviation Services,
Business Services,
Catering Services,
Cleaning and Maintenance Services,
Computer & Information Technology Services,
Construction Services,
Consulting Services,
Design Services,
Education and Training Services,
Electrical Services,
Emergency Services,
Engineering Services,
Environmental Services,
Fabrication Services,
Financial Services,
Forestry Services,
Health Services,
Legal Services,
Logistics Services,
Manufacturing Services,
Marine Services,
Marketing & Communications Services,
Mechanical Services,
Mining Services,
Packaging Services,
Painting Services,
Personal Services,
Power Generation Services,
Printing Services,
Real Estate Services,
Research, Development, and Testing Services,
Security Services,
Social Services,
Solar Energy Services,
Sports & Entertainment Services,
Surveying Services,
Telecommunications Services,
Tourism Services,
Traffic Services,
Transportation Services,
Urban Planning Services,
Less,
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-bbda89514b14> in <module>
#       4 driver = webdriver.Chrome()
#       5 driver.get(url)
# ----> 6 agri_bev = driver.find_elements_by_xpath('//*[@id="agriculture-food"]')[0].text
#       7 ener_env = driver.find_elements_by_xpath('//*[@id="energy-environment"]')[0].text
#       8 print(agri_bev,ener_env)
#
# IndexError: list index out of range

# %%
appa_textiles=driver.find_elements_by_xpath('//*[@id="apparel-textiles"]')[0].text
auto_trans = driver.find_elements_by_xpath('//*[@id="automobiles-transportation"]')[0].text
healt_beaut = driver.find_elements_by_xpath('//*[@id="health-beauty"]')[0].text
chem_metal = driver.find_elements_by_xpath('//*[@id="chemicals-minerals-metallurgy"]')[0].text
const_estate=driver.find_elements_by_xpath('//*[@id="construction-real-estate"]')[0].text
electronics=driver.find_elements_by_xpath('//*[@id="electronics-home-appliances-security"]')[0].text
telecom=driver.find_elements_by_xpath('//*[@id="electronics-components-telecommunications"]')[0].text
jwel=driver.find_elements_by_xpath('//*[@id="accessories-jewelries-bags"]')[0].text
gifts=driver.find_elements_by_xpath('//*[@id="gifts-toys-sports-entertainment"]')[0].text
furni=driver.find_elements_by_xpath('//*[@id="home-furniture-lights"]')[0].text
tools=driver.find_elements_by_xpath('//*[@id="machinery-tools-hardware"]')[0].text
instrum=driver.find_elements_by_xpath('//*[@id="measurement-analysis-instruments"]')[0].text
pack=driver.find_elements_by_xpath('//*[@id="packaging-advertising-office"]')[0].text
service=driver.find_elements_by_xpath('//*[@id="services"]')[0].text
end=driver.find_elements_by_xpath('//*[@id="root"]/div/section/header')[0].text
print(agri_bev)
print(ener_env)
print(appa_textiles)
print(auto_trans)
print(healt_beaut)
print(chem_metal)
print(const_estate)
print(electronics)
print(telecom)
print(jwel)
print(gifts)
print(furni)
print(tools)
print(instrum)
print(pack)
print(service)
